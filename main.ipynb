# %%
from transformers import pipeline


classifier = pipeline('sentiment-analysis')
classifier("suck it trabeck")

# %%
import pandas as pd 

csv = pd.read_csv('tezos_comments.csv')
df = pd.DataFrame(csv)

# %%
from transformers import pipeline
sentiment_pipeline = pipeline("sentiment-analysis")
# data = ["I love you", "I hate you"]
# sentiment_pipeline(data)
# psh = df["Comment"][0]
# for i in range(len(df)):
for word in df.Comment[0].split(' '):
    # print(word)
    x = sentiment_pipeline(word)
    print(x)
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# [{'label': 'NEGATIVE', 'score': 0.97596275806427}]
# [{'label': 'POSITIVE', 'score': 0.8405792117118835}]
# [{'label': 'POSITIVE', 'score': 0.9077640175819397}]
# [{'label': 'NEGATIVE', 'score': 0.9695221185684204}]
# [{'label': 'POSITIVE', 'score': 0.9946723580360413}]
# [{'label': 'POSITIVE', 'score': 0.9997854828834534}]
# [{'label': 'POSITIVE', 'score': 0.9987529516220093}]
# [{'label': 'POSITIVE', 'score': 0.9825525283813477}]
# [{'label': 'NEGATIVE', 'score': 0.9339755773544312}]
# [{'label': 'POSITIVE', 'score': 0.9932258725166321}]
# [{'label': 'POSITIVE', 'score': 0.9998134970664978}]
# [{'label': 'POSITIVE', 'score': 0.8405792117118835}]
# [{'label': 'NEGATIVE', 'score': 0.9413809776306152}]
# [{'label': 'POSITIVE', 'score': 0.987031877040863}]
# [{'label': 'NEGATIVE', 'score': 0.9736340641975403}]
# [{'label': 'POSITIVE', 'score': 0.9841646552085876}]
# [{'label': 'NEGATIVE', 'score': 0.9858442544937134}]
# [{'label': 'POSITIVE', 'score': 0.9872907996177673}]
# [{'label': 'POSITIVE', 'score': 0.9983637928962708}]
# [{'label': 'POSITIVE', 'score': 0.9193394780158997}]
# [{'label': 'POSITIVE', 'score': 0.9611782431602478}]
# [{'label': 'POSITIVE', 'score': 0.9998134970664978}]
# [{'label': 'NEGATIVE', 'score': 0.97596275806427}]
# [{'label': 'POSITIVE', 'score': 0.8405792117118835}]
# [{'label': 'POSITIVE', 'score': 0.9814918637275696}]
# [{'label': 'POSITIVE', 'score': 0.7284402847290039}]
# [{'label': 'POSITIVE', 'score': 0.994841992855072}]
# [{'label': 'POSITIVE', 'score': 0.9970609545707703}]
# [{'label': 'POSITIVE', 'score': 0.971549928188324}]
# [{'label': 'NEGATIVE', 'score': 0.9993669390678406}]
# [{'label': 'POSITIVE', 'score': 0.7667526006698608}]
# [{'label': 'POSITIVE', 'score': 0.7284402847290039}]
# [{'label': 'POSITIVE', 'score': 0.987365186214447}]
# [{'label': 'POSITIVE', 'score': 0.9924452900886536}]
# [{'label': 'POSITIVE', 'score': 0.9789573550224304}]
# [{'label': 'POSITIVE', 'score': 0.9542639255523682}]
# [{'label': 'NEGATIVE', 'score': 0.97596275806427}]
# [{'label': 'NEGATIVE', 'score': 0.9413809776306152}]
# [{'label': 'POSITIVE', 'score': 0.987031877040863}]
# [{'label': 'POSITIVE', 'score': 0.9635980725288391}]
# [{'label': 'POSITIVE', 'score': 0.989900529384613}]
# [{'label': 'POSITIVE', 'score': 0.9910536408424377}]
# [{'label': 'POSITIVE', 'score': 0.9991452693939209}]
# [{'label': 'POSITIVE', 'score': 0.9992244243621826}]
# [{'label': 'NEGATIVE', 'score': 0.99064701795578}]
# [{'label': 'POSITIVE', 'score': 0.9376327395439148}]
# [{'label': 'POSITIVE', 'score': 0.9676826596260071}]
# [{'label': 'POSITIVE', 'score': 0.9998134970664978}]
# [{'label': 'POSITIVE', 'score': 0.9946723580360413}]
# [{'label': 'POSITIVE', 'score': 0.9982988238334656}]
# [{'label': 'POSITIVE', 'score': 0.7563391923904419}]
# [{'label': 'POSITIVE', 'score': 0.9635980725288391}]
# [{'label': 'POSITIVE', 'score': 0.9965608716011047}]
# [{'label': 'POSITIVE', 'score': 0.962103545665741}]
# [{'label': 'NEGATIVE', 'score': 0.999076247215271}]
# [{'label': 'POSITIVE', 'score': 0.9927626252174377}]
# [{'label': 'POSITIVE', 'score': 0.9294742941856384}]
# [{'label': 'POSITIVE', 'score': 0.9970241189002991}]
# [{'label': 'POSITIVE', 'score': 0.9982348680496216}]
# [{'label': 'POSITIVE', 'score': 0.9978169202804565}]
# [{'label': 'NEGATIVE', 'score': 0.9975256323814392}]
# [{'label': 'POSITIVE', 'score': 0.9928129315376282}]
# [{'label': 'POSITIVE', 'score': 0.9700977802276611}]
# [{'label': 'POSITIVE', 'score': 0.962103545665741}]
# [{'label': 'POSITIVE', 'score': 0.9984523057937622}]
# [{'label': 'POSITIVE', 'score': 0.9619516730308533}]
# [{'label': 'POSITIVE', 'score': 0.9839435815811157}]
# [{'label': 'NEGATIVE', 'score': 0.9387929439544678}]
# [{'label': 'POSITIVE', 'score': 0.993144154548645}]
# [{'label': 'POSITIVE', 'score': 0.9982627034187317}]
# [{'label': 'POSITIVE', 'score': 0.9274747967720032}]
# [{'label': 'POSITIVE', 'score': 0.9983903169631958}]
# [{'label': 'POSITIVE', 'score': 0.9708179831504822}]
# [{'label': 'POSITIVE', 'score': 0.9540053606033325}]
# [{'label': 'POSITIVE', 'score': 0.9928129315376282}]
# [{'label': 'POSITIVE', 'score': 0.9869447350502014}]
# [{'label': 'NEGATIVE', 'score': 0.99064701795578}]
# [{'label': 'NEGATIVE', 'score': 0.6784093976020813}]
# [{'label': 'POSITIVE', 'score': 0.9873412251472473}]
# [{'label': 'POSITIVE', 'score': 0.9807174801826477}]
# [{'label': 'POSITIVE', 'score': 0.993144154548645}]
# [{'label': 'POSITIVE', 'score': 0.8220353722572327}]
# [{'label': 'POSITIVE', 'score': 0.993144154548645}]
# [{'label': 'POSITIVE', 'score': 0.9274747967720032}]
# [{'label': 'POSITIVE', 'score': 0.9131914973258972}]
# [{'label': 'POSITIVE', 'score': 0.9976160526275635}]
# [{'label': 'POSITIVE', 'score': 0.9652853012084961}]
# [{'label': 'NEGATIVE', 'score': 0.9846199154853821}]
# [{'label': 'NEGATIVE', 'score': 0.99064701795578}]
# [{'label': 'POSITIVE', 'score': 0.7409966588020325}]
# [{'label': 'POSITIVE', 'score': 0.991831362247467}]
# [{'label': 'POSITIVE', 'score': 0.9872907996177673}]
# [{'label': 'POSITIVE', 'score': 0.7030144929885864}]
# [{'label': 'POSITIVE', 'score': 0.9652853012084961}]
# [{'label': 'NEGATIVE', 'score': 0.8468783497810364}]
# [{'label': 'POSITIVE', 'score': 0.9984620809555054}]
# [{'label': 'POSITIVE', 'score': 0.945493757724762}]
# [{'label': 'POSITIVE', 'score': 0.9700977802276611}]
# [{'label': 'POSITIVE', 'score': 0.9972309470176697}]
# [{'label': 'POSITIVE', 'score': 0.9354605674743652}]
# [{'label': 'POSITIVE', 'score': 0.9991084933280945}]
# [{'label': 'POSITIVE', 'score': 0.8405792117118835}]
# [{'label': 'NEGATIVE', 'score': 0.9413809776306152}]
# [{'label': 'POSITIVE', 'score': 0.9700977802276611}]
# [{'label': 'POSITIVE', 'score': 0.993144154548645}]
# [{'label': 'NEGATIVE', 'score': 0.7697141170501709}]
# [{'label': 'POSITIVE', 'score': 0.7284402847290039}]
# [{'label': 'POSITIVE', 'score': 0.9703508019447327}]
# [{'label': 'POSITIVE', 'score': 0.9982988238334656}]
# [{'label': 'POSITIVE', 'score': 0.9708179831504822}]
# [{'label': 'POSITIVE', 'score': 0.9947645664215088}]
# [{'label': 'POSITIVE', 'score': 0.9989584684371948}]
# [{'label': 'POSITIVE', 'score': 0.9948587417602539}]
# [{'label': 'POSITIVE', 'score': 0.9635980725288391}]
# [{'label': 'POSITIVE', 'score': 0.9794236421585083}]
# [{'label': 'POSITIVE', 'score': 0.9911148548126221}]
# [{'label': 'POSITIVE', 'score': 0.5156886577606201}]
# [{'label': 'NEGATIVE', 'score': 0.9993669390678406}]
# [{'label': 'NEGATIVE', 'score': 0.9413809776306152}]
# [{'label': 'POSITIVE', 'score': 0.9784748554229736}]
# [{'label': 'POSITIVE', 'score': 0.9982988238334656}]
# [{'label': 'POSITIVE', 'score': 0.8932049870491028}]
# [{'label': 'POSITIVE', 'score': 0.9947645664215088}]
# [{'label': 'NEGATIVE', 'score': 0.9964459538459778}]
# [{'label': 'POSITIVE', 'score': 0.9989584684371948}]
# [{'label': 'POSITIVE', 'score': 0.9789573550224304}]
# [{'label': 'POSITIVE', 'score': 0.9911148548126221}]
# [{'label': 'POSITIVE', 'score': 0.8441722393035889}]
# [{'label': 'POSITIVE', 'score': 0.9994632601737976}]
# [{'label': 'NEGATIVE', 'score': 0.8791341185569763}]
# [{'label': 'POSITIVE', 'score': 0.9193394780158997}]
# [{'label': 'NEGATIVE', 'score': 0.97596275806427}]
# [{'label': 'NEGATIVE', 'score': 0.9736340641975403}]
# [{'label': 'POSITIVE', 'score': 0.9708179831504822}]
# [{'label': 'NEGATIVE', 'score': 0.96390300989151}]
# [{'label': 'NEGATIVE', 'score': 0.9413809776306152}]
# [{'label': 'POSITIVE', 'score': 0.9929903745651245}]
# [{'label': 'POSITIVE', 'score': 0.8846322894096375}]
# [{'label': 'NEGATIVE', 'score': 0.9992644190788269}]
# [{'label': 'NEGATIVE', 'score': 0.9997257590293884}]
# [{'label': 'POSITIVE', 'score': 0.8896528482437134}]
# [{'label': 'POSITIVE', 'score': 0.9708179831504822}]
# [{'label': 'NEGATIVE', 'score': 0.9927845001220703}]
# [{'label': 'POSITIVE', 'score': 0.9991018772125244}]
# [{'label': 'POSITIVE', 'score': 0.7284402847290039}]
# [{'label': 'NEGATIVE', 'score': 0.9885151982307434}]
# [{'label': 'POSITIVE', 'score': 0.9984523057937622}]
# [{'label': 'POSITIVE', 'score': 0.9619516730308533}]
# [{'label': 'POSITIVE', 'score': 0.9941204190254211}]
# [{'label': 'POSITIVE', 'score': 0.9984523057937622}]
# [{'label': 'POSITIVE', 'score': 0.9962683320045471}]
# [{'label': 'POSITIVE', 'score': 0.9635980725288391}]
# [{'label': 'POSITIVE', 'score': 0.9470561742782593}]
# [{'label': 'POSITIVE', 'score': 0.9789573550224304}]
# [{'label': 'POSITIVE', 'score': 0.9994632601737976}]
# [{'label': 'NEGATIVE', 'score': 0.980645477771759}]
# [{'label': 'POSITIVE', 'score': 0.7481209635734558}]
# [{'label': 'POSITIVE', 'score': 0.905363917350769}]
# [{'label': 'NEGATIVE', 'score': 0.6970564126968384}]
# [{'label': 'NEGATIVE', 'score': 0.5196114182472229}]

# %%
print(x.values)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_6825/4002244311.py in <module>
# ----> 1 print(x.values)
#
# AttributeError: 'list' object has no attribute 'values'
